# %% [markdown]
# # Ondas planas e raios em um meio de velocidade constante

# %%
from IPython.display import Image
Image(filename='images/raio_ondas_planas.png', width=1000)

# %% [markdown]
# #### Vagarosidade horizontal
#
# O espaço $\Delta s$ percorrido pela onda plana do tempo $t$ a $t + \Delta t$:
#
#
# $$\Delta s = \Delta x \cos \gamma = \Delta x \sin \theta$$
#
#
# Pois:
#
# $$\gamma = \frac{\pi}{2} - \theta$$
#
# $$\cos \gamma = \cos \left( \frac{\pi}{2} - \theta \right)$$
#
# $$\cos \gamma = \cos \frac{\pi}{2} \cos \theta + \sin \theta \sin \frac{\pi}{2}$$
#
# Por definição $\cos \frac{\pi}{2} = 0$ e $\sin \frac{\pi}{2} = 1$:
#
# $$\cos \gamma = \sin \theta$$
#
#
# A velocidade da onda plana no meio:
#
# $$ v = \frac{\Delta s}{\Delta t} = \frac{\Delta x \sin \theta}{\Delta t}$$
#
# $$ v \Delta t = \Delta x \sin \theta$$
#
# $$ \frac{\Delta t}{\Delta x} = \frac{\sin \theta}{v} = u \sin \theta \equiv p$$
#
# A vagarosidade é definida como $u=1/v$, $p$ é a chamada vagarosidade horizontal.

# %% [markdown]
# #### Vagarosidade vertical

# %%
from IPython.display import Image
Image(filename="images/vetorUePEta0.png",width=1000)

# %% [markdown]
# $$ \eta = u \cos \theta = (u^2 - p^2)^{1/2} $$
#
#
# Pois:
#
# $$ u^2 = p^2 + \eta^2$$
#
# Notar que no _turning point_, $p=u$ e $\eta=0$.

# %%
from IPython.display import Image
Image(filename='images/vetorUePEta1.png', width=1000)

# %%
from IPython.display import Image
Image(filename='images/vetorUeP2.png', width=1000)

# %%
from IPython.display import Image
Image(filename='images/vetorUePTP.png', width=1000)

# %%
from IPython.display import Image
Image(filename="images/turningPoint.png", width=1000)

# %%
from IPython.display import Image
Image(filename='images/raio.jpeg', width=800)

# %%
from IPython.display import Image
Image(filename='images/vetords.png', width=1000)

# %% [markdown]
# $$ \frac{dx}{ds} = \sin \theta = \frac{p}{u}$$
#
# $$ \frac{dz}{ds} = \cos \theta = (1 - \sin^2\theta)^{1/2}$$
#
# Lembrando que:
#
# $$\cos^2 \theta + \sin^2\theta=1$$
#
# Deste modo:
#
# $$\cos^2 \theta =1-\sin^2\theta$$
#
# $$\cos \theta =(1-\sin^2\theta)^{1/2}$$
#
# $$ \frac{dz}{ds} = \cos \theta = (1 - p^2/u^2)^{1/2} = (u^2/u^2 - p^2/u^2)^{1/2}= u^{-1}(u^2 - p^2)^{1/2}$$
#
# Da regra da cadeia:
#
# $$ \frac{dx}{dz} =
# \frac{dx}{ds} \frac{ds}{dz} = \frac{p}{u} \frac{u}{(u^2-p^2)^{1/2}} = \frac{p}{(u^2-p^2)^{1/2}} $$
#
#
# Integrando $x$ em $z$, de $z_1$ a $z_2$:
#
# $$ x(z_1,z_2,p)=p\int^{z_1}_{z_2} \frac{dz}{(u^2(z)-p^2)^{1/2}} $$
#
# Como o raio é simétrico em relação ao _turning point_, a distância total percorrida em $x$ será:
#
# $$ x(p)=2p\int^{z_p}_{0} \frac{dz}{(u^2(z)-p^2)^{1/2}}$$
#
# Definindo $dt=u ds$:
#
# $$ \frac{dt}{ds}=u$$
#
# Da regra da cadeia:
#
# $$ \frac{dt}{dz} = \frac{dt}{ds} \frac{ds}{dz} = u \frac{u}{(u^2-p^2)^{1/2}} = \frac{u^2}{(u^2-p^2)^{1/2}}$$
#
# Integrando $t$ em $z$, de $z_1$ a $z_2$:
#
# $$ t(z_1,z_2,p)=\int^{z_1}_{z_2} \frac{u^2(z)}{(u^2(z)-p^2)^{1/2}} dz$$
#
# Como o raio é simétrico em relação ao _turning point_, o tempo total em $t$ será:
#
# $$ t(p)=2\int^{z_p}_{0} \frac{u(z)^2}{(u^2(z)-p^2)^{1/2}} dz$$
