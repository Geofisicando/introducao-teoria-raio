# %% [markdown]
# # Cap2 - Solution of the Eikonal equation
#
# __Princípio__ significa o início, fundamento ou essência de algum fenômeno. Também pode ser definido como a causa primária, o momento, o local ou trecho em que algo, uma ação ou conhecimento tem origem. Sendo que o princípio de algo, seja como origem ou proposição pode ser questionado.
#
# > A trajetória percorrida pela luz ao se propagar de um ponto a outro é tal que o tempo
# > gasto em percorrê-la é um mínimo
#
# > A trajetória percorrida pela luz ao propagar-se de um ponto a outro é tal que o tempo gasto para
# > percorrê-la é estacionário a respeito das possíveis variações de sua trajetória

# %%
from IPython.display import Image
Image(filename='images/extremal.png', width=800)

# %% [markdown]
# > Os trajetos próximos ao 'verdadeiro' requerem tempos aproximadamente iguais

# %% [markdown]
# ### 2.1 Fermat's principle

# %%
from IPython.display import Image
Image(filename='images/fermat.png', width=900)

# %% [markdown]
# O tempo de trânsito em $l$ (funcional de Fermat):
#
# $$T(l)=\int_{(A)}^{(B)}dt=\int_{(A)}^{(B)}\frac{ds}{C}$$
#
# Pois,
#
# $$C=\frac{ds}{dt}$$
#
# Assim,
#
# $$dt=\frac{ds}{C}$$
#
# O funcional de Fermat é uma integral em coordenadas curvilíneas e pode ser reduzido para uma integral ordinária:
#
# $$ds=\sqrt{dx^2+dy^2+dz^2}=\sqrt{\dot{x}^2(\sigma)+\dot{y}^2(\sigma)+\dot{z}^2(\sigma)}d\sigma$$

# %%
from IPython.display import Image
Image(filename='images/arco2d.png', width=700)

# %% [markdown]
# Pois,
#
# $$\dot{x}=\frac{dx}{d\sigma}\to dx=\dot{x}d\sigma$$
#
# $$\dot{y}=\frac{dy}{d\sigma}\to dy=\dot{y}d\sigma$$
#
# $$\dot{z}=\frac{dz}{d\sigma}\to dz=\dot{z}d\sigma$$
#
# Logo,
#
# $$ds=\sqrt{dx^2+dy^2+dz^2}=\sqrt{(\dot{x}d\sigma)^2+(\dot{y}d\sigma)^2+(\dot{z}d\sigma)^2}=\sqrt{\dot{x}^2(\sigma)+\dot{y}^2(\sigma)+\dot{z}^2(\sigma)}d\sigma$$
#
# Assim,
#
# $$T(l)=\int_{(\sigma_A)}^{(\sigma_B)}\frac{\sqrt{\dot{x}^2(\sigma)+\dot{y}^2(\sigma)+\dot{z}^2(\sigma)}}{C(x(\sigma),y(\sigma),z(\sigma))}d\sigma=\int_{(\sigma_B)}^{(\sigma_A)}L(\dot{x},\dot{y},\dot{z},x,y,z)d\sigma$$
#
# Onde $L$ é a função Lagrangiana

# %% [markdown]
# ### 2.2 Variation of a functional; Euler's equation
#
# __Problema 1D__

# %%
from IPython.display import Image
Image(filename='images/problema1d.png', width=900)

# %% [markdown]
# $$T(l)=\int_{(A)}^{(B)}L(\dot{x}(\sigma),x(\sigma))d\sigma$$
#
# Definindo,
#
# $$x\to x(\sigma)+\delta x(\sigma)$$
#
# $$\dot{x}\to\dot{x}(\sigma)+\delta \dot{x}(\sigma)$$
#
# Assim,
#
# $$T(l)=\int_{(A)}^{(B)}L(\dot{x(\sigma)},x(\sigma))d\sigma$$
#
# $$T(l+\delta l)=\int_{(A)}^{(B)}L(\dot{x(\sigma)}+\delta \dot{x}(\sigma),x(\sigma)+\delta x)d\sigma$$
#
# __Expandindo $L$ em série de Taylor (Em relação a $\dot{x}$ e $x$, série de Taylor 2D):__
#
# $$L(\dot{x}+\delta \dot{x}(\sigma),x+\delta x)\approx L(\dot{x},x)+\frac{\partial L}{\partial \dot{x}}\delta \dot{x}
# +\frac{\partial L}{\partial x}\delta x+O(\delta x)^2$$
#
# Série de Taylor:
#
# $$f(x)\approx \sum_{n=0}^{\infty}\frac{f^{(n)}(x)\delta x^n}{n!}$$

# %% [markdown]
# Deste modo:
#
# $$\delta T(l)=T(l+\delta l)-T(l)$$
#
# $$=\int_{A}^{B}\left(\frac{\partial L}{\partial\dot{x}}\delta\dot{x}+\frac{\partial L}{\partial x}\delta x \right)+
# \int_{A}^{B}O(\delta x)^2d\sigma$$
#
# $\delta T$ é a primeira variação do funcional.
#
# $$\delta T=\int_{A}^{B}\left(\frac{\partial L}{\partial\dot{x}}\delta\dot{x}+\frac{\partial L}{\partial x}\delta x \right)d\sigma$$
#
# $\delta\dot{x}$ e $\delta x$ não são independentes. A fórmula da integração por partes:
#
# $$\int udv = uv - \int vdu$$
#
# Integrando por partes:
#
# $$u=\frac{\partial L}{\partial\dot{x}}$$
#
# $$v=\delta x$$
#
# $$du=\frac{d}{d\sigma}\frac{\partial L}{\partial\dot{x}}d\sigma$$
#
# $$dv=\frac{d}{d\sigma}\delta x=\delta\dot{x}$$
#
# Assim,
#
# $$\delta T = \left.\frac{\partial L}{\partial\dot{x}}\delta x\right|_{A}^{B}+
# \int_{A}^{B}\left(\frac{\partial L}{\partial x}-\frac{d}{d\sigma}\frac{\partial L}{\partial\dot{x}}\right)\delta xd\sigma$$
#
# Esta é a fórmula para a primeira variação do funcional com pontos móveis ($\delta x|_A$ e $\delta x|_B$
# arbitrários).

# %% [markdown]
# No caso de pontos A e B fixos:
#
# $$\delta x|_A=\delta x|_b=0$$
#
# e,
#
# $$\delta T = \int_{A}^{B}\left(\frac{\partial L}{\partial x}-\frac{d}{d\sigma}\frac{\partial L}{\partial\dot{x}}\right)\delta xd\sigma$$
#
# Observe:

# %%
from IPython.display import Image
Image(filename='images/problema1ddeltax.png', width=900)

# %% [markdown]
# Se A e B são fixos, $\delta x|_A$ e $\delta x|_B$ são iguais a zero. Pelo princípio de Fermat:
#
# $$\delta T = \int_{A}^{B}\left(\frac{\partial L}{\partial x}-\frac{d}{d\sigma}\frac{\partial L}{\partial\dot{x}}\right)\delta xd\sigma = 0$$
#
# Assim, estabelecemos a __Equação de Euler__:
#
# $$\frac{\partial L}{\partial x}-\frac{d}{d\sigma}\frac{\partial L}{\partial\dot{x}}=0$$

# %% [markdown]
# __Problema em 3D__
#
# $$T(l)=\int_{A}^{B}L(\dot{x},\dot{y},\dot{z},x,y,z)d\sigma$$
#
# Definimos:
#
# $$x \to x+\delta x$$
#
# $$\dot{x} \to \dot{x}+\delta \dot{x}$$
#
# $$y \to y+\delta y$$
#
# $$\dot{y} \to \dot{y}+\delta \dot{y}$$
#
# $$z \to z+\delta z$$
#
# $$\dot{z} \to \dot{z}+\delta \dot{z}$$
#
# Repetindo os cálculos do problema 1D para todas as coordenadas:
#
# $$T(l+\delta l)=\int_{A}^{B}L(\dot{x}+\delta \dot{x},\dot{y}+\delta \dot{y},\dot{z}+\delta \dot{z},x+\delta x,y+\delta y,z+\delta z)d\sigma$$
#
# Expandindo L em série de Taylor em relação a $\dot{x}$ e $x$:
#
# $$L(x+\delta x)\approx L(\dot{x},x)+\frac{\partial L}{\partial\dot{x}}\delta\dot{x}+\frac{\partial L}{\partial x}\delta x+O(\delta x)^2$$
#
# Em relação a $\dot{y}$ e $y$:
#
# $$L(y+\delta y)\approx L(\dot{y},y)+\frac{\partial L}{\partial\dot{y}}\delta\dot{y}+\frac{\partial L}{\partial y}\delta y+O(\delta y)^2$$
#
# Em relação a $\dot{z}$ e $z$:
#
# $$L(z+\delta z)\approx L(\dot{z},z)+\frac{\partial L}{\partial\dot{z}}\delta\dot{z}+\frac{\partial L}{\partial z}\delta z+O(\delta z)^2$$
#
# Superpondo as soluções:
#
# $$L(x+\delta x,y+\delta y,z+\delta z)\approx L(x,y,z)+\frac{\partial L}{\partial\dot{x}}\delta\dot{x}+\frac{\partial L}{\partial x}\delta x
# +\frac{\partial L}{\partial\dot{y}}\delta\dot{y}+\frac{\partial L}{\partial y}\delta y
# +\frac{\partial L}{\partial\dot{z}}\delta\dot{z}+\frac{\partial L}{\partial z}\delta z+\dots$$

# %% [markdown]
# Assim,
#
# $$\delta T(l)=T(l+\delta l)-T(l)$$
#
# $$=\int_{A}^{B} \left\{\left(\frac{\partial L}{\partial\dot{x}}\delta\dot{x}+\frac{\partial L}{\partial x}\delta x\right)
# +\left(\frac{\partial L}{\partial\dot{y}}\delta\dot{y}+\frac{\partial L}{\partial y}\delta y\right)
# +\left(\frac{\partial L}{\partial\dot{z}}\delta\dot{z}+\frac{\partial L}{\partial z}\delta z\right)
# \right\}d\sigma$$
#
# Integrando por partes o primeiro termo de cada um dos parênteses:
#
# __Para x__
#
# $$u=\frac{\partial L}{\partial\dot{x}}\,\,\,\, v=\delta x$$
#
# $$du=\frac{d}{d\sigma}\frac{\partial L}{\partial\dot{x}}d\sigma\,\,\,\, dv=\delta\dot{x}$$
#
# $$\int_{A}^{B} \left(\frac{\partial L}{\partial\dot{x}}\delta\dot{x}+\frac{\partial L}{\partial x}\delta x\right)d\sigma=\frac{\partial L}{\partial\dot{x}}\delta x|_{A}^{B}
# +\int_{A}^{B}\left(\frac{\partial L}{\partial x}-\frac{d}{d\sigma}\frac{\partial L}{\partial\dot{x}}\right)\delta x d\sigma$$
#
# __Para y__
#
# $$u=\frac{\partial L}{\partial\dot{y}}\,\,\,\, v=\delta y$$
#
# $$du=\frac{d}{d\sigma}\frac{\partial L}{\partial\dot{y}}d\sigma\,\,\,\, dv=\delta\dot{y}$$
#
# $$\int_{A}^{B} \left(\frac{\partial L}{\partial\dot{y}}\delta\dot{y}+\frac{\partial L}{\partial y}\delta y\right)d\sigma=\frac{\partial L}{\partial\dot{y}}\delta y|_{A}^{B}
# +\int_{A}^{B}\left(\frac{\partial L}{\partial y}-\frac{d}{d\sigma}\frac{\partial L}{\partial\dot{y}}\right)\delta y d\sigma$$
#
# __Para z__
#
# $$u=\frac{\partial L}{\partial\dot{z}}\,\,\,\, v=\delta z$$
#
# $$du=\frac{d}{d\sigma}\frac{\partial L}{\partial\dot{z}}d\sigma\,\,\,\, dv=\delta\dot{z}$$
#
# $$\int_{A}^{B} \left(\frac{\partial L}{\partial\dot{z}}\delta\dot{z}+\frac{\partial L}{\partial z}\delta z\right)d\sigma=\frac{\partial L}{\partial\dot{z}}\delta z|_{A}^{B}
# +\int_{A}^{B}\left(\frac{\partial L}{\partial z}-\frac{d}{d\sigma}\frac{\partial L}{\partial\dot{z}}\right)\delta z d\sigma$$
#
# Assim,
#
# $$\delta T= \left( \frac{\partial L}{\partial\dot{x}}\delta x +
# \frac{\partial L}{\partial\dot{y}}\delta y +
# \frac{\partial L}{\partial\dot{z}}\delta z
# \right)|_{A}^{B}
# +\int_{A}^{B}\left\{\left(\frac{\partial L}{\partial x}-\frac{d}{d\sigma}\frac{\partial L}{\partial\dot{x}}\right)\delta\dot{x}+
# \left(\frac{\partial L}{\partial y}-\frac{d}{d\sigma}\frac{\partial L}{\partial\dot{y}}\right)\delta\dot{y}+
# \left(\frac{\partial L}{\partial z}-\frac{d}{d\sigma}\frac{\partial L}{\partial\dot{z}}\right)\delta\dot{z}
# \right\}d\sigma$$
#
# Da mesma forma ($A$ e $B$ fixos):
#
# $$\delta x|_A=\delta x|_B=0$$
#
# $$\delta y|_A=\delta y|_B=0$$
#
# $$\delta z|_A=\delta z|_B=0$$

# %% [markdown]
# Daí resulta:
#
# $$\frac{d}{d\sigma}\frac{\partial L}{\partial\dot{x}}-\frac{\partial L}{\partial x}=0$$
#
# $$\frac{d}{d\sigma}\frac{\partial L}{\partial\dot{y}}-\frac{\partial L}{\partial y}=0$$
#
# $$\frac{d}{d\sigma}\frac{\partial L}{\partial\dot{z}}-\frac{\partial L}{\partial z}=0$$
#
# Qualquer solução da equação de Euler é um extremal do cálculo variacional e um raio na geofísica.

# %% [markdown]
# Relembrando a regra da cadeia:
#
# $$\frac{\partial y(u(t))}{\partial t}=\frac{\partial y}{\partial u}\frac{\partial u}{\partial t}$$
#
# Deste modo,
#
# $$\frac{\partial L}{\partial\dot{x}}=
# \frac{\partial}{\partial\dot{x}}\left(\frac{\sqrt{\dot{x}^2+\dot{y}^2+\dot{z}^2}}{C(x,y,z)}\right)
# =\frac{1}{C}\frac{1}{2\sqrt{\dot{x}^2+\dot{y}^2+\dot{z}^2}}2\dot{x}=\frac{\dot{x}}{C\sqrt{\dot{x}^2+\dot{y}^2+\dot{z}^2}}$$

# %% [markdown]
# E,
#
# $$\frac{\partial L}{\partial x}=
# \frac{\partial}{\partial x}\left(\frac{\sqrt{\dot{x}^2+\dot{y}^2+\dot{z}^2}}{C(x,y,z)}\right)$$
#
# Aplicando a regra do produto e a regra da cadeia para resolver estas derivadas:
#
# $$\frac{\partial L}{\partial x}=
# \frac{\partial}{\partial x}\left(\sqrt{\dot{x}^2+\dot{y}^2+\dot{z}^2}\right)\frac{1}{C}
# +\sqrt{\dot{x}^2+\dot{y}^2+\dot{z}^2}\frac{\partial}{\partial x}\frac{1}{C}$$
#
# Logo,
#
# $$\frac{\partial L}{\partial x}=
# \sqrt{\dot{x}^2+\dot{y}^2+\dot{z}^2}\frac{\partial}{\partial x}\frac{1}{C}$$
#
# Resultados semelhantes serão obtidos para $\frac{\partial L}{\partial y}$, $\frac{\partial L}{\partial \dot{y}}$,
# $\frac{\partial L}{\partial z}$ e $\frac{\partial L}{\partial \dot{z}}$. Assim,
#
# $$\frac{d}{d\sigma}\left(\frac{\dot{x}}{\sqrt{\dot{x}^2+\dot{y}^2+\dot{z}^2}}\frac{1}{C}\right)
# -\sqrt{\dot{x}^2+\dot{y}^2+\dot{z}^2}\frac{\partial}{\partial x}\frac{1}{C}=0$$
#
# $$\frac{d}{d\sigma}\left(\frac{\dot{y}}{\sqrt{\dot{x}^2+\dot{y}^2+\dot{z}^2}}\frac{1}{C}\right)
# -\sqrt{\dot{x}^2+\dot{y}^2+\dot{z}^2}\frac{\partial}{\partial y}\frac{1}{C}=0$$
#
# $$\frac{d}{d\sigma}\left(\frac{\dot{z}}{\sqrt{\dot{x}^2+\dot{y}^2+\dot{z}^2}}\frac{1}{C}\right)
# -\sqrt{\dot{x}^2+\dot{y}^2+\dot{z}^2}\frac{\partial}{\partial z}\frac{1}{C}=0$$

# %% [markdown]
# __Exemplo 1:__ Tomando o parâmetro $s$ (comprimento do arco ao longo do raio) ao invés de $\sigma$.
#
# $$ds=\sqrt{\dot{x}^2+\dot{y}^2+\dot{z}^2}d\sigma$$
#
# logo,
#
# $$\frac{d}{ds}=\frac{1}{\sqrt{\dot{x}^2+\dot{y}^2+\dot{z}^2}}\frac{d}{d\sigma}$$

# %% [markdown]
# Deste modo, (o mesmo vale para $y$ e $z$):
#
# $$\frac{d}{d\sigma}\left(\frac{\dot{x}}{\sqrt{\dot{x}^2+\dot{y}^2+\dot{z}^2}}\frac{1}{C}\right)
# -\sqrt{\dot{x}^2+\dot{y}^2+\dot{z}^2}\frac{\partial}{\partial x}\frac{1}{C}
# =0$$
#
# $$\sqrt{\dot{x}^2+\dot{y}^2+\dot{z}^2}\frac{d}{ds}\left(\frac{\dot{x}}{\sqrt{\dot{x}^2+\dot{y}^2+\dot{z}^2}}\frac{1}{C}\right)-\sqrt{\dot{x}^2+\dot{y}^2+\dot{z}^2}\frac{\partial}{\partial x}\frac{1}{C}=0$$
#
# Portanto,
#
# $$\frac{d}{ds}\left(\frac{1}{\sqrt{\dot{x}^2+\dot{y}^2+\dot{z}^2}}\frac{dx}{d\sigma}\frac{1}{C}\right)
# -\frac{\partial}{\partial x}\frac{1}{C}=0$$
#
# $$\frac{d}{ds}\left(\frac{1}{C}\frac{dx}{ds}\right)-\frac{\partial}{\partial x}\frac{1}{C}=0$$

# %% [markdown]
# Assim,
#
# $$\frac{d}{ds}\left(\frac{1}{C}\frac{dx}{ds}\right)-\frac{\partial}{\partial x}\frac{1}{C}=0$$
#
# $$\frac{d}{ds}\left(\frac{1}{C}\frac{dy}{ds}\right)-\frac{\partial}{\partial y}\frac{1}{C}=0$$
#
# $$\frac{d}{ds}\left(\frac{1}{C}\frac{dz}{ds}\right)-\frac{\partial}{\partial z}\frac{1}{C}=0$$

# %% [markdown]
# Na forma vetorial:
#
# $$\frac{d}{ds}\left(\frac{\vec{t}}{C}\right)-\nabla(1/C)=0$$
#
# Onde:
#
# $$\vec{t}=\frac{dx}{ds}\hat{i}+\frac{dy}{ds}\hat{j}+\frac{dz}{ds}\hat{k}$$
#
# $\vec{t}$ é o vetor tangente unitário tangente ao raio.

# %% [markdown]
# __Exemplo 2: Meio homogêneo, C constante__
#
# $$\frac{\partial}{\partial x}\frac{1}{C}=\frac{\partial}{\partial y}\frac{1}{C}=\frac{\partial}{\partial z}\frac{1}{C}=0$$
#
# Isto significa que o lado direito da equação de Euler:
#
# $$\frac{d}{ds}\left(\frac{1}{C}\frac{dx}{ds}\right)=0$$
#
# $$\frac{1}{C}\frac{dx}{ds}=a_1=constante$$
#
# Assim,
#
# $$\frac{dx}{ds}=a_1C\to\int\frac{dx}{ds}ds=\int a_1Cds$$
#
# Então:
#
# $$x(s)=a_1Cs+x(0)$$
#
# Perceba:
#
# $$x(s)|_{s=0}=x(0)$$
#
# Isto posto, para x:
#
# $$\frac{1}{C}\frac{dx}{ds}=a_1$$
#
# $$x=a_1Cs+x(0)$$
#
# Para y:
#
# $$\frac{1}{C}\frac{dy}{ds}=a_2$$
#
# $$y=a_2Cs+y(0)$$
#
# Para z:
#
# $$\frac{1}{C}\frac{dz}{ds}=a_3$$
#
# $$z=a_3Cs+z(0)$$

# %% [markdown]
# Então,
#
# $$x-x(0)=a_1Cs+x(0)-x(0)$$
#
# $$x-x(0)=a_1Cs$$
#
# Da mesma forma,
#
# $$y-y(0)=a_2Cs$$
#
# $$z-z(0)=a_3Cs$$

# %% [markdown]
# Logo,
#
# $$s=\sqrt{(x-x(0))^2+(y-y(0))^2+(z-z(0))^2}$$
#
# $$s=\sqrt{a_1^2C^2s^2+a_2^2C^2s^2+a_3^2C^2s^2}$$
#
# Portanto,
#
# $$s=Cs\sqrt{a_1^2+a_2^2+a_3^2}$$
#
# $$\frac{1}{C}=\sqrt{a_1^2+a_2^2+a_3^2}$$

# %% [markdown]
# ### 2.3 Hamilton form of the functional and Euler's equation
#
# __No caso 1D__
#
# $$T=\int_{A}^{B}L(\dot{x},x)d\sigma$$
#
# $$H=(p\dot{x}-L)|_{\dot{x}=\dot{x}(p)}$$
#
# $$H=H(p,x)$$
#
# $$L=p\dot{x}-H$$
#
# Introduzindo o slowness generalizado $p=\partial L/\partial\dot{x}$ e a partir de agora devemoss encontrar
# $\dot{x}$ como uma função de $p,\dot{x}=\dot{x}(p)$. Em mecânica, $H$ significa a energia mecânica do sistema.
#
# $$T=\int_{A}^{B}L(\dot{x},x)d\sigma=\int_{A}^{B}(p\dot{x}-H(p,x))d\sigma$$
#
# $$T=\int_{A}^{B}pdx-H(p,x)d\sigma$$
#
# Primeira variação de $T$:
#
# $$x\to x+\delta x$$
#
# $$p\to p+\delta p$$

# %% [markdown]
# Expandindo em série de Taylor ao redor de $\delta x$ e $\delta p$:
#
# $$L(x+\delta x,p+\delta p)\approx p\dot{x}-H+\dot{x}\delta p+p\frac{\partial\dot{x}}{\partial p}\delta p-\frac{\partial H}{\partial p}\delta p+\frac{\partial p}{\partial x}\dot{x}\delta x+p\frac{\partial\dot{x}(p)}{\partial x}\delta x-\frac{\partial H}{\partial x}\delta x$$
#
# $$L(x+\delta x,p+\delta p)\approx p\dot{x}-H+\dot{x}\delta p+p\delta\dot{x}-\frac{\partial H}{\partial p}\delta p-\frac{\partial H}{\partial x}\delta x$$
#
# Onde,
#
# $$\frac{\partial\dot{x}}{\partial p}=\frac{\delta\dot{x}}{\delta p}\to\delta\dot{x}=\frac{\partial\dot{x}}{\partial p}\delta p$$
#
# Logo, a diferença
#
# $$L(x+\delta x,p+\delta p)-L(x,p)\approx \dot{x}\delta p+p\delta\dot{x}-\frac{\partial H}{\partial p}\delta p-\frac{\partial H}{\partial x}\delta x$$
#
# Assim,
#
# $$\delta T=\int_{A}^{B}\left(\dot{x}\delta p+p\delta\dot{x}-\frac{\partial H}{\partial p}\delta p-\frac{\partial H}{\partial x}\delta x\right)d\sigma$$

# %% [markdown]
# Tomando a segunda parcela do integrando:
#
# $$\int_{A}^{B}p\delta\dot{x}d\sigma$$
#
# Relembrando a integração por partes:
#
# $$\int udv=uv-\int vdu$$
#
# Deste modo:
#
# $$u=p$$
#
# $$dv=\delta\dot{x}d\sigma$$
#
# $$du=\frac{\partial p}{\partial\sigma}d\sigma$$
#
# $$v=\delta x$$
#
# Assim,
#
# $$\int_{A}^{B}p\delta\dot{x}d\sigma=p\delta x|_{A}^{B}-
# \int_{A}^{B}\delta x\frac{\partial p}{\partial\sigma}d\sigma
# =p\delta x|_{A}^{B}-
# \int_{A}^{B}\dot{p}\delta xd\sigma$$

# %% [markdown]
# Substituindo na integral para $\delta T$:
#
# $$\delta T=p\delta x|_{A}^{B}+\int_{A}^{B}\left(\dot{x}\delta p-\dot{p}\delta x-\frac{\partial H}{\partial p}\delta p-\frac{\partial H}{\partial x}\delta x\right)d\sigma$$
#
# Então:
#
# $$\delta T=p\delta x|_{A}^{B}+\int_{A}^{B}\left\{\left(\dot{x}-\frac{\partial H}{\partial p}\right)\delta p-\left(\dot{p}+\frac{\partial H}{\partial x}\right)\delta x\right\}d\sigma$$
#
# Então, se $\delta x|_{A}^{B}=0$ e na condição de extremo do funcional $\delta T=0$,
# as __Equações de Hamilton__:
#
# $$\dot{x}=\frac{\partial H}{\partial p}$$
#
# $$\dot{p}=-\frac{\partial H}{\partial x}$$
#
# Onde:
#
# $$x=x(\sigma)$$
#
# $$p=p(\sigma)$$

# %% [markdown]
# __Extensão para 3D__
#
# $$p_1=\frac{\partial L}{\partial\dot{x}}$$
#
# $$p_2=\frac{\partial L}{\partial\dot{y}}$$
#
# $$p_3=\frac{\partial L}{\partial\dot{z}}$$
#
# $$H=p_1\dot{x}+p_2\dot{y}+p_3\dot{z}-L$$
#
# $$T=\int_{A}^{B}L d\sigma=\int_{A}^{B}p_1\dot{x}+p_2\dot{y}+p_3\dot{z}-H d\sigma$$
#
# Assim,
#
# $$\delta T=(p_1\dot{x}+p_2\dot{y}+p_3\dot{z})|_{A}^{B}
# +\int_{A}^{B}\left\{\left(\dot{x}-\frac{\partial H}{\partial p_1}\right)\delta p_1
# +\left(\dot{y}-\frac{\partial H}{\partial p_2}\right)\delta p_2
# +\left(\dot{z}-\frac{\partial H}{\partial p_3}\right)\delta p_3
# -\left(\dot{p_1}+\frac{\partial H}{\partial x}\right)\delta x
# -\left(\dot{p_2}+\frac{\partial H}{\partial y}\right)\delta y
# -\left(\dot{p_3}+\frac{\partial H}{\partial z}\right)\delta z
# \right\}d\sigma$$
#
# As equações de Euler na forma Hamiltoniana derivadas a partir de $\delta T$:
#
# $$\dot{x}=\frac{\partial H}{\partial p_1}$$
#
# $$\dot{p_1}=-\frac{\partial H}{\partial x}$$
#
# $$\dot{y}=\frac{\partial H}{\partial p_2}$$
#
# $$\dot{p_2}=-\frac{\partial H}{\partial y}$$
#
# $$\dot{z}=\frac{\partial H}{\partial p_3}$$
#
# $$\dot{p_3}=-\frac{\partial H}{\partial z}$$

# %% [markdown]
# ### 2.4 Solution of the eikonal equation in the case of a point source

# %%
from IPython.display import Image
Image(filename='images/pointsource.png', width=900)

# %% [markdown]
# $$\vec{r}(\sigma)=x(\sigma)\hat{i}+y(\sigma)\hat{j}+z(\sigma)\hat{k}$$
#
# $$\vec{r}(\sigma)\Big|_{\sigma=0}=\vec{r}_A$$
#
# $$\frac{d\vec{r}}{d\sigma}\Big|_{\sigma=0}=\vec{t}$$

# %% [markdown]
# __Definition:__ We say that this family of rays form a regular field of rays in a domain $\Omega$ if for each
# point $M \in \Omega$ there is one and only one ray which starts at $A$ and reaches $M$.
#
# (i) For each $M \in \Omega$ we must find the ray which reachs $M$.
#
# (ii) Then we must compute Fermat's integral $T=\int_{A}^{M}ds/C$ along this ray between $A$ and $M$.
# We thus obtain a function of $M$ which we denote $\tau(M)=\tau(x,y,z)$,
#
# $$\tau(M)=\int_{A}^{M}\frac{ds}{C}=\int_{A}^{M}\frac{\sqrt{\dot{x}^2+\dot{y}^2+\dot{z}^2}}{C(x,y,z)}d\sigma$$
#
# $M$, movel. $A$ fixo.
#
# This function $\tau(x,y,z)$ will satisfy the eikonal equation.
#
# $$\delta T=\left(\frac{\partial L}{\partial\dot{x}}\delta x+
# \frac{\partial L}{\partial\dot{y}}\delta y+
# \frac{\partial L}{\partial\dot{z}}\delta z\right)\Bigg|_M+
# \int_{A}^{M}\left\{
# \left(\frac{\partial L}{\partial x}-\frac{d}{d\sigma}\frac{\partial L}{\partial\dot{x}}\right)\delta x+
# \left(\frac{\partial L}{\partial y}-\frac{d}{d\sigma}\frac{\partial L}{\partial\dot{y}}\right)\delta y+
# \left(\frac{\partial L}{\partial z}-\frac{d}{d\sigma}\frac{\partial L}{\partial\dot{z}}\right)\delta z
# \right\}d\sigma$$
#
# As each time we compute $T$ on a ray, Euler's equation are satisfaied and because of that integral in equation
# vanishes, so
#
# $$\delta T\equiv d\tau=\left(\frac{\partial L}{\partial\dot{x}}\delta x+
# \frac{\partial L}{\partial\dot{y}}\delta y+
# \frac{\partial L}{\partial\dot{z}}\delta z\right)\Bigg|_M=\frac{\partial\tau}{\partial x}dx
# +\frac{\partial\tau}{\partial y}dy
# +\frac{\partial\tau}{\partial z}dz$$
#
# e,
#
# $$dx=\delta x|_M$$
#
# $$dy=\delta y|_M$$
#
# $$dz=\delta z|_M$$
#
# Assim,
#
# $$\frac{\partial\tau}{\partial x}=\frac{\partial L}{\partial\dot{x}}
# =\frac{\dot{x}}{C\sqrt{\dot{x}^2+\dot{y}^2+\dot{z}^2}}=\frac{1}{C\sqrt{\dot{x}^2+\dot{y}^2+\dot{z}^2}}\frac{dx}{d\sigma}$$
#
# $$\frac{\partial\tau}{\partial y}=\frac{\partial L}{\partial\dot{y}}
# =\frac{\dot{y}}{C\sqrt{\dot{x}^2+\dot{y}^2+\dot{z}^2}}=\frac{1}{C\sqrt{\dot{x}^2+\dot{y}^2+\dot{z}^2}}\frac{dy}{d\sigma}$$
#
# $$\frac{\partial\tau}{\partial z}=\frac{\partial L}{\partial\dot{z}}
# =\frac{\dot{z}}{C\sqrt{\dot{x}^2+\dot{y}^2+\dot{z}^2}}=\frac{1}{C\sqrt{\dot{x}^2+\dot{y}^2+\dot{z}^2}}\frac{dz}{d\sigma}$$
#
# A função $\tau(M)$ satisfaz a equação eikonal:
#
# $$(\nabla\tau)^2=\frac{\dot{x}^2+\dot{y}^2+\dot{z}^2}{C^2(\dot{x}^2+\dot{y}^2+\dot{z}^2)}=\frac{1}{C^2}$$

# %% [markdown]
# Definition: Surfaces in 3D, defined by $\tau=cont$, are called wavefrontfs.
#
# $$\frac{\partial\tau}{\partial x}dx+\frac{\partial\tau}{\partial y}dy+\frac{\partial\tau}{\partial z}dz=0$$
#
# $$\nabla\tau\cdot d\vec{r}$$
#
# $d\vec{r}$ pertence ao plano tangente à superfície $\tau=const$.
#
# Definindo os operadores:
#
# $$d\sigma\to\ ds$$
#
# $$\frac{d}{ds}=\frac{1}{\sqrt{\dot{x}^2+\dot{y}^2+\dot{z}^2}}\frac{d}{d\sigma}$$
#
# Assim,
#
# $$\frac{\partial\tau}{\partial x}=\frac{1}{C}\frac{dx}{\sqrt{\dot{x}^2+\dot{y}^2+\dot{z}^2}}d\sigma$$
#
# $$\frac{\partial\tau}{\partial x}=\frac{1}{C}\frac{dx}{ds}$$
#
# O mesmo vale para $\frac{\partial\tau}{\partial y}$ e $\frac{\partial\tau}{\partial z}$. Deste modo,
#
# $$\nabla\tau\equiv\frac{\partial\tau}{\partial x}\hat{i}+\frac{\partial\tau}{\partial y}\hat{j}+\frac{\partial\tau}{\partial z}\hat{k}$$
#
# $$\nabla\tau=\frac{1}{C}\left(\frac{dx}{ds}\hat{i}+\frac{dy}{ds}\hat{j}+\frac{dz}{ds}\hat{k}\right)=\frac{1}{C}\vec{t}$$
#
# Onde $\vec{t}$ é o vetor tangente unitário ao raio

# %% [markdown]
# ### 2.5 Solution of the eikonal equation when an initial wave is given
#
# $$\tau=\tau_0=const$$
#
# $$\tau=\tau(M)=\int_{M_0}{M}\frac{ds}{C}+\tau_0$$

# %%
from IPython.display import Image
Image(filename='images/surface.png', width=900)

# %% [markdown]
# When the integral is a curvilinear integral along that unique ray which starts at $M_0$ reaches $M$. In a
# homogeneous medium this procedure coincides with _Huygens principle_.
#
# > Each point on a wavefront $t=t_0$ is considered as a secondary
# > source, which irradiates a spherical wavefront that propagates
# > during a time interval $\Delta t$. An envelope of these spherical
# > waves describes the wavefront at $t=t_0+\Delta t$
